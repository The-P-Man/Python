# %% [markdown]
# # Playtime with Python
# Time for some Python fun

# %%
x = 'hello world'
print(x)
# Out:
# hello world

# %%
for i in range(5):
    print('hello world')
# Out:
# hello world
# hello world
# hello world
# hello world
# hello world

# %%
for i in range(10):
    print(i, i**2, i**3)
# Out:
# 0 0 0
# 1 1 1
# 2 4 8
# 3 9 27
# 4 16 64
# 5 25 125
# 6 36 216
# 7 49 343
# 8 64 512
# 9 81 729

# %%
import matplotlib.pyplot as plt
with plt.xkcd():
    plt.xlabel('Time Learning Python / Days')
    plt.ylabel('Proficiency / Unknown Units')
    plt.title('XKCD Style')
    plt.plot([1,2,3,4,5,6], [1,4,9,16,25,36])

# %%
# %whos

# %% [markdown]
# The end ...if you want it to be...
